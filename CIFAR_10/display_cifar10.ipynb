# %%
import pickle
import numpy as np
import random
import PIL
from matplotlib import pyplot as plt
# %matplotlib inline
from IPython.display import Image

# %% [markdown]
# ### Create label dictionary

# %%
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

class_labels = {}
for i in range(0, len(classes)):
    class_labels[i] = classes[i]

print(class_labels)
# Out:
# {0: 'plane', 1: 'car', 2: 'bird', 3: 'cat', 4: 'deer', 5: 'dog', 6: 'frog', 7: 'horse', 8: 'ship', 9: 'truck'}

# %% [markdown]
# ## Visualize RGB

# %%
def unpickleSomething(path, filename):
    with open(path+filename, 'rb') as picklefile: 
        data = pickle.load(picklefile)
        return data
    

def makeRGB(array):
    """data shape
       h, w, 3 
       color_channels: R, G, B = 3
    """
    pass

def saveAsPNG(array, id):
    img_path = "/Users/susmitadatta/Metis/Proj03/CIFAR_10/Images/"
    img_name = "img_"+str(id)+".png"
    #array.save(img_path+img_name)
    plt.imsave(img_path+img_name, array)

def visualizeRGB():
    """visualize some samples in the training datasets """
    
    disp_per_class = 10
    disp_window = 1
    num_classes = len(classes)
    
    display = []
    
    pickle_path = "/Users/susmitadatta/Metis/Proj03/CIFAR_10/ImageData/"
    x_trn = unpickleSomething(pickle_path, 'img_train.p')
    y_trn = unpickleSomething(pickle_path, 'label_train.p')
    
    for key in class_labels:
        indices = [i for i, y in enumerate(y_trn) if y == key]
        display.append(random.sample(indices, disp_per_class ))
        
    for i in range(0, len(display)):
        for ind in display[i]:
            
            img_array = x_trn[ind]
    
            R = img_array[0, :, :]
            G = img_array[1, :, :]
            B = img_array[2, :, :]
    
            RGB_array = np.dstack((R, G, B))
            RGB_image = PIL.Image.fromarray(RGB_array, 'RGB')
            
            plt.subplot(num_classes, disp_per_class,  disp_window)  
            plt.imshow(RGB_image, interpolation="None")
            plt.axis('off')
            
            disp_window = disp_window + 1
    plt.show()

# %%
visualizeRGB()
